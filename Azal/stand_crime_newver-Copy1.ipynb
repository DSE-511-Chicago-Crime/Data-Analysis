# %%
print('import libraries Pandas  and numpy')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# import libraries Pandas  and numpy

# %%
#Read csv file for 
print('download datframes for Chicago crimes as csv files  for 2016, 2017, 2018, 2019, 2020 and 2021 years')
dat_2016 = pd.read_csv("../data/2016_crime.csv")
dat_2017 = pd.read_csv("../data/2017_crime.csv")
dat_2018 = pd.read_csv("../data/2018_crime.csv") 
dat_2019 = pd.read_csv("../data/2019_crime.csv") 
dat_2020 = pd.read_csv("../data/2020_crime.csv")
dat_2021= pd.read_csv("../data/2021_crime.csv")
# dat_2017
dat_2016
# dat_2018
# #dat_2019
# Out:
# download datframes for Chicago crimes as csv files  for 2016, 2017, 2018, 2019, 2020 and 2021 years
#         Unnamed: 0  unique_key                       date  \
# 0                0    10410713  2016-02-11 03:00:00+00:00
# 1                1    10428442  2016-02-26 08:15:00+00:00
# 2                2    10443848  2016-03-10 04:14:00+00:00
# 3                3    10449270  2016-03-15 02:00:00+00:00
# 4                4    10469505  2016-03-31 12:54:00+00:00
# ...            ...         ...                        ...
# 269636      269636    10457260  2016-02-12 06:50:17+00:00
# 269637      269637    10663271  2016-08-30 07:53:00+00:00
# 269638      269638    10503113  2016-04-28 06:20:00+00:00
# 269639      269639    10712599  2016-10-11 07:25:00+00:00
# 269640      269640    10718590  2016-09-30 11:56:41+00:00
#
#                                       block  iucr                primary_type  \
# 0                      079XX S WOODLAWN AVE  0265         CRIM SEXUAL ASSAULT
# ...

# %%
# building function to great a new dataframe consisting of just two featurs,distrcts and primary_type
def extrat_featur (arg):
    data=arg[['district','primary_type']]
    return data
print('new shape data for 2016')
new_shape_data_2016= extrat_featur(dat_2016)
print('new shape data for 2017 dataframe')
new_shape_data_2017=extrat_featur(dat_2017)
print('new shape data for 2018dataframe ')
new_shape_data_2018=extrat_featur(dat_2018)
print('new shape data for 2019 dataframe')
new_shape_data_2019=extrat_featur(dat_2019)
print('new shape data for 2020 dataframe')
new_shape_data_2020=extrat_featur(dat_2020)
print('new shape data for 2021 dataframe')
new_shape_data_2021=extrat_featur(dat_2021)
# Out:
# new shape data for 2016
# new shape data for 2017 dataframe
# new shape data for 2018dataframe
# new shape data for 2019 dataframe
# new shape data for 2020 dataframe
# new shape data for 2021 dataframe

# %%
# build function to get the unique of primary_type and district
print('building function to find out the unique district and  primary_type of crimes')
#def uniq_data (df_dat): 
    #get_uniq_data= df_dat.unique()
    #return get_uniq_data
    # print(get_uniq_data)
    
#print('the unique district and primary_type for 2016')
#uniq_district_2016 =uniq_data(dat_2016['district']) 
# uniq_primary_type_2016=uniq_data (dat_2016['primary_type'])    
# print('the unique district and primary_type for 2017')
# uniq_district_2017=uniq_data (dat_2017['district']) 
# uniq_primary_type_2017=uniq_data (dat_2017['primary_type']) 
# print('the unique district and primary_type for 2018')
# uniq_district_2018=uniq_data (dat_2018['district']) 
# uniq_primary_type_2018=uniq_data (dat_2018['primary_type'])    
# print('the unique district and primary_type for 2019')
# uniq_district_2019=uniq_data (dat_2019['district']) 
# uniq_primary_type_2019=uniq_data (dat_2019['primary_type'])

# print('the unique district and primary_type for 2020')
# uniq_district_2020=uniq_data (dat_2020['district'])
# uniq_primary_type_2020=uniq_data (dat_2020['primary_type'])
# print('the unique district and primary_type for 2021')
# uniq_district_2021=uniq_data (dat_2021['district'])
# uniq_primary_type_2021=uniq_data (dat_2021['primary_type'])
# Out:
# building function to find out the unique district and  primary_type of crimes

# %%
#build function to group primary_type and district
print('building function to group number of crimes per district')
def grop_dat (df):
    group_crim_distr=df.groupby(['district'])[['primary_type']].count()
    return group_crim_distr
#     print(group_crim_distr)
#     print(len(group_crim_distr))
print('grouping number of crimes per distric in 2016')
grouped_crim_per_dist_2016=grop_dat(new_shape_data_2016)
print('grouping number of crimes per distric in 2017')
grouped_crim_per_dist_2017=grop_dat(new_shape_data_2017)     
print('grouping number of crimes per distric in 2018') 
grouped_crim_per_dist_2018=grop_dat(new_shape_data_2018)        
print('grouping number of crimes per distric in 2019')
grouped_crim_per_dist_2019=grop_dat(new_shape_data_2019)
print('grouping number of crimes per each distric in 2020')
grouped_crim_per_dist_2020=grop_dat(new_shape_data_2020)
print('grouping number of crimes per each distric in 2021')
grouped_crim_per_dist_2021=grop_dat(new_shape_data_2021)
#print('grouping number of crimes per distric in 2016')
# grouped_crim_per_dist_2019=grop_dat(dat_2019)
# print('grouping number of crimes per distric in 2019')
# grouped_crim_per_dist_2019=grop_dat(dat_2019)
# print('grouping number of crimes per distric in 2020')
# grouped_crim_per_dist_2020=grop_dat(dat_2020)
# print('grouping number of crimes per distric in 2021')
# grouped_crim_per_dist_2021=grop_dat(dat_2021)
# Out:
# building function to group number of crimes per district
# grouping number of crimes per distric in 2016
# grouping number of crimes per distric in 2017
# grouping number of crimes per distric in 2018
# grouping number of crimes per distric in 2019
# grouping number of crimes per each distric in 2020
# grouping number of crimes per each distric in 2021

# %%
print(grouped_crim_per_dist_2016['primary_type'].to_list())
#print(grouped_crim_per_dist_2016.index.to_list())

#grouped_crim_per_dist_2016
# grouped_crim_per_dist_2017
#grouped_crim_per_dist_2018
#grouped_crim_per_dist_2019
# grouped_crim_per_dist_2020
#grouped_crim_per_dist_2021
#print(grouped_crim_per_dist_2016)
print('nnnnnn')
#grouped_crim_per_dist_2017
# Out:
# [13738, 11453, 12349, 15017, 11637, 16211, 14225, 17548, 12675, 12587, 18646, 14081, 10339, 11428, 9474, 7785, 13226, 12258, 4405, 8629, 7356, 14559, 15]
# nnnnnn

# %%
#initializing data for plotting the three years,2016,2017, and 2018 befor covid for primary_type of crime per district


# Year 2016
districts_2016=grouped_crim_per_dist_2016.index.to_list()
y1=np.array(grouped_crim_per_dist_2016['primary_type'])
x1=np.arange(len(y1))
# year 2017
districts_2017=grouped_crim_per_dist_2017.index.to_list()
y2=np.array(grouped_crim_per_dist_2017['primary_type'])
x2=np.arange(int(len(y2)))
# Year 2018
districts_2018=grouped_crim_per_dist_2018.index.to_list()
y3=np.array(grouped_crim_per_dist_2018['primary_type'])
x3=np.arange(len(y3))

# %%
## visualizing  the number of primary_type of crimes per distric Chicago state USA
##(x1,y1) label for data of Year 2016, (x2,y2) label  for data of Year 2017, (x3,y3) label  for data of Year 2018
#plt.figure(figsize=(12,3))
fig, axes = plt.subplots(5, 2, figsize=(20, 5))
fig.subplots_adjust(top=0.8)
width = 0.2
# primar_type  numbers of crimes per distric for year 2016 Plot
plt.subplot(1,3,1)
plt.bar(x1,y1)
plt.ylabel(' Number of primary_type of Crimes for per distict')
plt.xticks(x1,districts_2016,rotation=-67)
plt.xlabel('primar_type numbers of\n crimes per distric for Year 2016')
# primar_type  numbers of crimes per distric for year 2017 Plot
plt.subplot(1,3,2)
plt.bar(x1,y1)
#plt.ylabel(' Number of primary_type of Crimes for per distict')
plt.xticks(x2,districts_2017,rotation=-67)
plt.xlabel('primar_type numbers of\n crimes per distric for Year 2017')
# primar_type  numbers of crimes per distric for year 2018 Plot
plt.subplot(1,3,3)
plt.bar(x3,y3)
#plt.ylabel(' Number of primary_type of Crimes for per distict')
plt.xticks(x3,districts_2018,rotation=-67,horizontalalignment='right')
plt.xlabel('primary_type numbers of\n crimes per distric for Year 2018')
plt.suptitle('The primary_type of Crimes Per Distric of Chicago State USA\n for the years Before Covid-19: 2016, 2017, 2018 reports')
plt.show()

# %% [markdown]
# ###  Observation
#  Through the years 2016, 2017, and 2018 each district had not faced a big change in the numbers of crimes, almost similar. However, in 2018, the figures of crimes for district codes one and 18 increased up to 15700 and 16222 after they were around 13735 and 13250, respectively.

# %%
#initializing data for plotting the three years,2019,2020, and 2021 during covid-19 for primary_type of crime per district
# Year 2019
districts_2019=grouped_crim_per_dist_2019.index.to_list()
y4=np.array(grouped_crim_per_dist_2019['primary_type'])
x4=np.arange(len(y4))
# year 2020
districts_2020=grouped_crim_per_dist_2020.index.to_list()
y5=np.array(grouped_crim_per_dist_2020['primary_type'])
x5=np.arange(int(len(y5)))
# Year 2021
districts_2021=grouped_crim_per_dist_2021.index.to_list()
y6=np.array(grouped_crim_per_dist_2021['primary_type'])
x6=np.arange(len(y6))

# %%
## visualizing  the number of primary_type of crimes per distric Chicago state USA
##(x1,y1) label for data of Year 2016, (x2,y2) label  for data of Year 2017, (x3,y3) label  for data of Year 2018
#plt.figure(figsize=(12,3))
fig, axes = plt.subplots(5, 2, figsize=(20, 5))
fig.subplots_adjust(top=0.8)
# primar_type  numbers of crimes per distric for year 2019 Plot
plt.subplot(1,3,1)
plt.bar(x4,y4)
plt.ylabel(' Number of primary_type of Crimes for per distict')
plt.xticks(x4,districts_2019,rotation=-67)
plt.xlabel('primar_type numbers of\n crimes per distric for Year 2019')
# primar_type  numbers of crimes per distric for year 2020 Plot
plt.subplot(1,3,2)
plt.bar(x5,y5)
#plt.ylabel(' Number of primary_type of Crimes for per distict')
plt.xticks(x5,districts_2020,rotation=-67)
plt.xlabel('primar_type numbers of\n crimes per distric for Year 2020')
# primar_type  numbers of crimes per distric for year 2021 Plot
plt.subplot(1,3,3)
plt.bar(x6,y6)
#plt.ylabel(' Number of primary_type of Crimes for per distict')
plt.xticks(x3,districts_2021,rotation=-67,horizontalalignment='right')
plt.xlabel('primary_type numbers of\n crimes per distric for Year 2021')
plt.suptitle('The primary_type of Crimes Per Distric of Chicago State USA\n for The years during Covid-19: 2019, 2020, 2021 reports')
plt.show()

# %% [markdown]
# ### Observations
# The three figures for years during Covid -19 show a noticeable decrease in the level of crimes in all districts, particularly in the areas with large-scale criminal activities from more than 18000 in 2019 to less than 16000 and 12000 in 2020 and 2021 numbers of crime respectively.

# %%
## find the percent change of the primary_type of crimes per distric for 
##                                        1- Among the three years befor Covid-19 (2016,2017,and 2018) 
##                                        2- Between the years 2018 and biging of covid 2019
##                                        3- Among the three years of Covid-19 (2019,2020,and 2021)

    
## Between the years (2016,2017)

grouped_crim_per_dist_2017['Percent_Change_prim_typ_2017']=(((grouped_crim_per_dist_2017['primary_type']-grouped_crim_per_dist_2016['primary_type'])/grouped_crim_per_dist_2016['primary_type'])*100)
print(grouped_crim_per_dist_2017['Percent_Change_prim_typ_2017'])


## Between the years (2017,2018)
grouped_crim_per_dist_2018['Percent_Change_prim_typ_2018']=(((grouped_crim_per_dist_2018['primary_type']-grouped_crim_per_dist_2017['primary_type'])/grouped_crim_per_dist_2017['primary_type'])*100)
print(grouped_crim_per_dist_2018['Percent_Change_prim_typ_2018'])

## Between the years (2018,2019)
grouped_crim_per_dist_2019['Percent_Change_prim_typ_2019']=(((grouped_crim_per_dist_2019['primary_type']-grouped_crim_per_dist_2018['primary_type'])/grouped_crim_per_dist_2018['primary_type'])*100)
print(grouped_crim_per_dist_2019['Percent_Change_prim_typ_2019'])

## Between the years (2019, 2020)
grouped_crim_per_dist_2020['Percent_Change_prim_typ_2020']=(((grouped_crim_per_dist_2020['primary_type']-grouped_crim_per_dist_2019['primary_type'])/grouped_crim_per_dist_2019['primary_type'])*100)
print(grouped_crim_per_dist_2020['Percent_Change_prim_typ_2020'])

## Between the years (2020,2021)
grouped_crim_per_dist_2021['Percent_Change_prim_typ_2021']=(((grouped_crim_per_dist_2021['primary_type']-grouped_crim_per_dist_2020['primary_type'])/grouped_crim_per_dist_2020['primary_type'])*100)
print(grouped_crim_per_dist_2021['Percent_Change_prim_typ_2021'])
# Out:
# district
# 1.0     12.228854
# 2.0      1.606566
# 3.0      2.890922
# 4.0     -1.724712
# 5.0      1.065567
# 6.0      2.122016
# 7.0     -2.804921
# 8.0     -5.658765
# 9.0     -7.140039
# 10.0    -0.500516
# 11.0    -3.196396
# 12.0    -3.976990
# 14.0    -2.553438
# 15.0   -10.579279
# 16.0    -5.615368
# 17.0     1.734104
# 18.0    14.206865
# 19.0    -1.484745
# 20.0     4.426788
# 22.0    -3.001507
# 24.0    11.636759
# 25.0    -1.971289
# 31.0   -80.000000
# Name: Percent_Change_prim_typ_2017, dtype: float64
# district
# 1       1.829031
# 2       2.363152
# 3      -4.493940
# 4      -3.672584
# 5       2.168183
# 6      -0.054364
# 7       3.616375
# 8      -0.809423
# 9      -5.887850
# 10      1.045992
# 11      6.626039
# 12     -2.677317
# 14     -6.640199
# 15     -1.164498
# 16     -1.565645
# 17     -3.358586
# 18      7.394902
# 19      1.888042
# 20      7.804348
# 22      1.397849
# 24     -5.808573
# 25     -6.067825
# 31    233.333333
# ...

# %%
## initializing plotting percent change for all the years from 2016 to 2021 included

## between 2016 and 2017 

districts_present_change_2017=grouped_crim_per_dist_2017.index.to_list()
y7=np.array(grouped_crim_per_dist_2017['primary_type'])
x7=np.arange(len(y7))

## between 2017 and 2018
districts_present_change_2018=grouped_crim_per_dist_2018.index.to_list()
y8=np.array(grouped_crim_per_dist_2018['primary_type'])
x8=np.arange(len(y8))

## between 2018 and 2019
districts_present_change_2019=grouped_crim_per_dist_2019.index.to_list()
y9=np.array(grouped_crim_per_dist_2019['primary_type'])
x9=np.arange(len(y9))

## between 2019 and 2020
districts_present_change_2020=grouped_crim_per_dist_2020.index.to_list()
y10=np.array(grouped_crim_per_dist_2020['primary_type'])
x10=np.arange(len(y10))

## between 2020 and 2021
districts_present_change_2021=grouped_crim_per_dist_2021.index.to_list()
y11=np.array(grouped_crim_per_dist_2021['primary_type'])
x11=np.arange(len(y11))

# %%
## visualizing  the percentde chanage of primary_type of crimes per distric Chicago state USA from 2016 to 2021 included
##(x7,y7) label for data of Year 2017, (x8,y8) label  for data of Year 2018, (x9,y9) label  for data of Year 2019,
##(x10,y10) label  for data of Year 2020, (x11,y11) label  for data of Year 2021
fig.subplots_adjust(top=0.5)
plt.figure(figsize=(45,8))
#fig, axes = plt.subplots(2, 3, figsize=(10, 5))
#fig, axes = plt.subplots(2, 2, figsize=(20, 5))
#  percentage chanage of primar_type numbers of crimes per distric for year 2017 Plot
rows, cols = 2, 5
plt.subplot(rows, cols, 1)
plt.bar(x7,y7)
plt.ylabel(' Percentage chanage of primary_type\n of Crimes for per distict %')
plt.xticks(x7,districts_2017,rotation=-67)
plt.xlabel(' Percentage Chanage of Primar_type numbers of\n crimes per distric for Year 2017')
#  percentage chanage of primar_type numbers of crimes per distric for year 2018 Plot
plt.subplot(rows, cols, 2)
#plt.subplot()
plt.bar(x8,y8)
#plt.ylabel(' Percentage chanage of primary_type of Crimes for per distict %')
plt.xticks(x8,districts_2018,rotation=-67)
plt.xlabel(' Percentage Chanage of Primar_type numbers of\n crimes per distric for Year 2018')
plt.title('The percentage change of primary_type of Crimes Per Distric of Chicago\nState USA for The years before Covid-19: 2016, 2017, 2018 reports')
plt.show()
#  percentage chanage of primar_type numbers of crimes per distric for year 2019 Plot
#plt.subplot(1,3,3)
fig.subplots_adjust(top=0.7)
plt.figure(figsize=(85,25))
rows, cols = 3, 5
plt.subplot(rows, cols, 1)
plt.bar(x9,y9)
plt.ylabel(' Percentage chanage of primary_type of\n Crimes for per distict %')
plt.xticks(x7,districts_2019,rotation=-67)
plt.xlabel(' Percentage Chanage of Primar_type numbers of\n crimes per distric for Year 2019')
#  percentage chanage of primar_type numbers of crimes per distric for year 2020 Plot
plt.subplot(rows, cols, 2)
#plt.subplot(1,3,2)
plt.bar(x10,y10)
#plt.ylabel(' Percentage chanage of primary_type of Crimes for per distict %')
plt.xticks(x10,districts_2020,rotation=-67)
plt.xlabel(' Percentage Chanage of Primar_type numbers of\n crimes per distric for Year 2020')
#  percentage chanage of primar_type numbers of crimes per distric for year 2021 Plot
plt.subplot(rows, cols, 3)
#plt.subplot(1,3,3)
plt.bar(x11,y11)
#plt.ylabel(' Percentage chanage of primary_type of Crimes for per distict %')
plt.xticks(x11,districts_2021,rotation=-67)
plt.xlabel(' Percentage Chanage of Primar_type numbers of\n crimes per distric for Year 2021')
plt.title('The percentage change of primary_type of Crimes Per Distric of Chicago\n State USA for The years during Covid-19: 2019, 2020, 2021 reports',fontsize=16)
plt.tight_layout()
plt.show()

# %%
#initializing data for plotting the three years,2016,2017, and 2018 befor covid for primary_type of crime per district

fig, ((ax1,ax2,ax3,),(ax4,ax5,ax6)) = plt.subplots(nrows=2, ncols=3,figsize=(12,4))

# Year 2016
districts_2016=grouped_crim_per_dist_2016.index.to_list()
y1=np.array(grouped_crim_per_dist_2016['primary_type'])
x1=np.arange(len(y1))
ax1.bar(x1,y1,width=0.3,label='2016')
ax1.set_xticks(x1)
ax1.set_xticklabels(districts_2016,rotation=-7,fontsize=7)
ax1.set_ylabel('Number of primary_type \nof Crimes for per distict')
ax1.set_xlabel('primary_type numbers of\n crimes per distric for Year 2016')
ax1.legend()
ax1.set_ylim(0,20000)

# year 2017

districts_2017=grouped_crim_per_dist_2017.index.to_list()
y2=np.array(grouped_crim_per_dist_2017['primary_type'])
x2=np.arange(len(y2))
ax2.bar(x2,y2,width=0.3,label='2017')
ax2.set_xticks(x2)
ax2.set_xticklabels(districts_2017,rotation=-45,fontsize=7)
#ax2.set_ylabel('Number of primary_type of Crimes for per distict')
ax2.set_xlabel('primary_type numbers of\n crimes per distric for Year 2017')
ax2.legend()
ax2.set_ylim(0,20000)

# Year 2018
districts_2018=grouped_crim_per_dist_2018.index.to_list()
y3=np.array(grouped_crim_per_dist_2018['primary_type'])
x3=np.arange(len(y3))
ax3.bar(x3,y3,width=0.3,label='2018')
ax3.set_xticks(x3)
ax3.set_xticklabels(districts_2018,rotation=-7,fontsize=7)
#ax3.set_ylabel('Number of primary_type of Crimes for per distict')
ax3.set_xlabel('primary_type numbers of\n crimes per distric for Year 2018')
ax3.legend()
ax3.set_ylim(0,20000)

#initializing data for plotting the three years,2019,2020, and 2021 during covid-19 for primary_type of crime per district

# Year 2019
districts_2019= grouped_crim_per_dist_2019.index.to_list()
y4=np.array(grouped_crim_per_dist_2019['primary_type'])
x4=np.arange(len(y4))
ax4.bar(x4,y4,width=0.3,label='2019')
ax4.set_ylabel(' Number of primary_type \nof Crimes for per distict')
ax4.set_xticks(x4)
ax4.set_xticklabels(districts_2019,rotation=-7,fontsize=7)
ax4.set_xlabel('primary_type numbers of\n crimes per distric for Year 2019')
ax4.legend()
ax4.set_ylim(0,20000)

# year 2020
districts_2020=grouped_crim_per_dist_2020.index.to_list()
y5=np.array(grouped_crim_per_dist_2020['primary_type'])
x5=np.arange(len(y5))
ax5.bar(x5,y5,width=0.3,label='2020')
ax5.set_xticks(x5)
ax5.set_xticklabels(districts_2020,rotation=-7,fontsize=7)
#ax5.set_ylabel('Number of primary_type of Crimes for per distict')
ax5.set_xlabel('primary_type numbers of\n crimes per distric for Year 2020')
ax5.legend()
ax5.set_ylim(0,20000)

# Year 2021
districts_2021=grouped_crim_per_dist_2021.index.to_list()
y6=np.array(grouped_crim_per_dist_2021['primary_type'])
x6=np.arange(len(y6))
ax6.bar(x6,y6,width=0.3,label='2021')
ax6.set_xticks(x6)
ax6.set_xticklabels(districts_2021,rotation=-7,fontsize=7)
#ax6.set_ylabel('Number of primary_type of Crimes for per distict')
ax6.set_xlabel('primary_type numbers of\n crimes per distric for Year 2021')
ax6.legend()
ax6.set_ylim(0,20000)
fig.tight_layout(pad=0.5)
plt.show()

# %%
fig, ((ax1,ax2,ax3,ax4),(ax5,ax6,ax7,ax8)) = plt.subplots(nrows=2, ncols=4,figsize=(12,4))
default_vec_time = [default_rf_fitting_vec_time,default_lg_fitting_vec_time,default_sv_fitting_vec_time]
x = np.arange(len(default_vec_time))
ax1.bar(x, default_vec_time, width=0.3, label='default_param')
ax1.set_xticks(x)
ax1.set_xticklabels(['RF', 'LR', 'SVM'])
ax1.set_title('feature extraction fitting time')
ax1.set_ylabel('time(s)')
ax1.set_xlabel('Classifiers')
ax1.legend()


















rows, cols = 2, 2
plt.subplot(rows, cols, 1)
plt.pie([1, 2, 3])
plt.title("Figure 1")
plt.subplot(rows, cols, 2)
plt.pie([3, 4, 5])
plt.title("Figure 2")
plt.subplot(rows, cols, 3)
plt.pie([6, 7, 8])
plt.title("Figure 3")
plt.subplot(rows, cols, 4)
plt.pie([8, 9, 10])
plt.title("Figure 4")

















fig.subplots_adjust(top=0.8)

axes[0,0].plot(data)
axes[0,0].set_title("\n".join(["this is a really long title"]*2))
axes[0,1].plot(data)
axes[1,1].plot(data)

fig.suptitle("\n".join(["a big long suptitle that runs into the title"]*2), y=0.98)

def compute_death_rate(arg1,arg2):
    return ((arg2-arg1)/arg1 *100))



grouped_crim_per_dist_2017['Percent_Change_D_R'] = grouped_crim_per_dist_2017.apply(lambda x: compute_death_rate(x.primary_type, x.Case_Fatality_Ratio),axis=1)
#print(myslection_col_bef_chrs)




















data = np.random.random(size=100)

fig, axes = plt.subplots(2, 2, figsize=(10, 5))
fig.subplots_adjust(top=0.8)

axes[0,0].plot(data)
axes[0,0].set_title("\n".join(["this is a really long title"]*2))
axes[0,1].plot(data)
axes[1,1].plot(data)

fig.suptitle("\n".join(["a big long suptitle that runs into the title"]*2), y=0.98)

plt.show()
# Out:
#   File "<ipython-input-15-749d5138b1b7>", line 69
#     return ((arg2-arg1)/arg1 *100))
#                                   ^
# SyntaxError: unmatched ')'

# %%
## visualizing  the top five USA states in incident rate










##(x1,y1) label for before Chris, (x2,y2) label during Chris, (x3,y3) label for after Chis

plt.figure(figsize=(8,4))
# before Christmas plot
plt.subplot(1,3,1)
plt.bar(x1,y1)
plt.ylabel('Incident Rate for COIVD 19 per 100k person')
plt.xticks(x1,top_5_states_incidentrate_bef_chrs,rotation=-60)
plt.xlabel('7-days before Chrismats')
# during Chritmas plot
plt.subplot(1,3,2)
plt.bar(x2,y2)
plt.xticks(x2,top_5_states_incidentrate_chrs,rotation=-60)
plt.xlabel('During Chrismats')
plt.yticks(visible=False)
# after Christmase plot
plt.subplot(1,3,3)
plt.bar(x3,y3)
plt.xticks(x3,top_5_states_incidentrate_aft_chrs,rotation=-60)
plt.xlabel('7-days after Chrismats')
plt.yticks(visible=False)
plt.suptitle('The top 5 US states in incident rate \n 12-18-2020, 12-25-2020, 01-01-2021 reports')
plt.show()
